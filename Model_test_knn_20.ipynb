# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_pickle('Prediction_master_number_attempt_knn_20.pkl')
data.columns
# Out:
# Index(['DATE', 'PLAYER', 'TEAM', 'POSITION', 'DK_SAL', 'DK_PTS_PER_MIN',
#        'MINUTES', 'DraftKings_PTS', 'magic_number_knn_20'],
#       dtype='object')

# %%
dates = data.DATE.unique()
date_range = ['02/01/2018', '02/02/2018', '02/03/2018', '02/04/2018',
       '02/05/2018', '02/06/2018', '02/07/2018', '02/08/2018',
       '02/09/2018', '02/10/2018', '02/11/2018', '02/12/2018',
       '02/13/2018', '02/14/2018', '02/15/2018', '02/22/2018',
       '02/23/2018', '02/24/2018', '02/25/2018', '02/26/2018',
       '02/27/2018', '02/28/2018', '03/01/2018', '03/02/2018',
       '03/03/2018', '03/04/2018', '03/05/2018', '03/06/2018',
       '03/07/2018', '03/08/2018', '03/09/2018', '03/10/2018',
       '03/11/2018', '03/12/2018', '03/13/2018', '03/14/2018',
       '03/15/2018', '03/16/2018', '03/17/2018', '03/18/2018',
       '03/19/2018', '03/20/2018', '03/21/2018', '03/22/2018',
       '03/23/2018', '03/24/2018', '03/25/2018', '03/26/2018',
       '03/27/2018', '03/28/2018', '03/29/2018', '03/30/2018',
       '03/31/2018']

# %%
day = data.loc[(data.DATE == '02/14/2018')]

# %%
day.sort_values('magic_number_knn_20', ascending = False, inplace=True)

day
# Out:
# /Users/willhall/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#              DATE             PLAYER           TEAM POSITION  DK_SAL  \
# 43813  02/14/2018  Russell Westbrook  Oklahoma City       PG   11300
# 43844  02/14/2018      Anthony Davis    New Orleans       PF   11600
# 43803  02/14/2018       James Harden        Houston       PG   11400
# 43873  02/14/2018       Kevin Durant   Golden State       SF    9400
# 43705  02/14/2018        Ben Simmons   Philadelphia       PG    8000
# 43889  02/14/2018     Damian Lillard       Portland       PG    8800
# 43824  02/14/2018       Tyreke Evans        Memphis       SF    7600
# 43874  02/14/2018     Draymond Green   Golden State       PF    3000
# 43804  02/14/2018         Chris Paul        Houston       PG    9500
# 43877  02/14/2018      Stephen Curry   Golden State       PG    9300
# 43748  02/14/2018     DeAndre Jordan    LA Clippers        C    7300
# 43713  02/14/2018     Victor Oladipo        Indiana       SG    9600
# 43769  02/14/2018         Kyle Lowry        Toronto       PG    7400
# 43732  02/14/2018       Bradley Beal     Washington       SG    8900
# 43693  02/14/2018   Hassan Whiteside          Miami        C    7400
# 43760  02/14/2018       Kyrie Irving         Boston       PG    8300
# 43846  02/14/2018       Jrue Holiday    New Orleans       PG    8100
# 43858  02/14/2018      Elfrid Payton        Phoenix       PG    7500
# 43822  02/14/2018         Marc Gasol        Memphis        C    7500
# 43675  02/14/2018       Kemba Walker      Charlotte       PG    8600
# 43751  02/14/2018       Lou Williams    LA Clippers       SG    6800
# 43664  02/14/2018     Andre Drummond        Detroit        C   10600
# 43673  02/14/2018      Dwight Howard      Charlotte        C    8200
# 43674  02/14/2018      Nicolas Batum      Charlotte       SG    6200
# 43809  02/14/2018        Paul George  Oklahoma City       SF    9800
# 43866  02/14/2018        Rudy Gobert           Utah        C    7600
# 43737  02/14/2018   Tim Hardaway Jr.       New York       SG    5500
# 43719  02/14/2018    DeMarre Carroll       Brooklyn       SF    5700
# 43836  02/14/2018      Isaiah Thomas      LA Lakers       PG    5800
# 43868  02/14/2018   Donovan Mitchell           Utah       SG    7900
# ...           ...                ...            ...      ...     ...
# 43861  02/14/2018       Troy Daniels        Phoenix       SG    3600
# 43786        0.665529    14.65            9.75             0.000214
# 43891        0.531377     9.88            5.25             0.000211
# 43791        0.834543    34.45           28.75             0.000211
# 43870        0.264658    12.28            3.25             0.000205
# 43687        0.705128    19.50           13.75             0.000202
# 43700        0.731982     8.88            6.50             0.000202
# 43852        0.667604    14.23            9.50             0.000198
# 43817        0.203459     9.83            2.00             0.000196
# 43838        0.304878    11.48            3.50             0.000188
# 43777        2.318841     3.45            8.00             0.000183
# 43842        0.000000     4.53            0.00             0.000168
# 43755        0.443262     2.82            1.25             0.000167
# 43850        0.328272    24.37            8.00             0.000165
# 43819        1.016865    10.08           10.25             0.000164
# 43828        0.790788    18.02           14.25             0.000163
# 43812        0.314597    11.92            3.75             0.000162
# 43816        0.879044    21.33           18.75             0.000152
# 43808        0.293586    11.07            3.25             0.000147
# 43742        0.596783    19.27           11.50             0.000144
# 43881        0.541191    16.63            9.00             0.000142
# 43776        0.709939     4.93            3.50             0.000131
# 43788        0.593220     5.90            3.50             0.000127
# 43689        0.566343    15.45            8.75             0.000123
# 43884        0.000000     2.83            0.00             0.000107
# 43679        0.608447    13.97            8.50             0.000094
# 43818        1.580460     3.48            5.50             0.000085
# 43872        0.354890    12.68            4.50             0.000079
# 43716        0.540070    14.35            7.75             0.000052
#
# [242 rows x 9 columns]

# %%
# 0 = index
# 1 = Date
# 2 = Name
# 3 = Team
# 4 = Position
# 5 = DK_SAL
# 6 = DraftKings_PTS
# 7 = DK_PTS_pred
# 8 = VALUE
# 9 = VALUE_pred
# 10 = CAP_HIT
# 11 = CAP_VALUE
# 12 = CAP_VALUE_pred
# 13 = magic_number
# 14 = magic_number_pred
# 15 = add

# %%
budget = 50000
spots = 8
roster = []
positions = []
needs = {'PG': 1,'SG': 1,'SF': 1,'PF': 1,'C': 1,'PG_SG': 1,'SF_PF': 1 ,'Util': 1}
pred_output = []
output = []
spent = 0
while spots >= 1:
    for line in day.itertuples():
        if line[5] <= (budget/spots):   #6250
            if line[2] not in roster:
                if line[4] == 'PG':
                    if needs['PG'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['PG'] -= 1
                        break
                    if needs['PG_SG'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['PG_SG'] -= 1
                        break
                    if needs['Util'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['Util'] -= 1
                        break
                    else:
                        continue
                if line[4] == 'SG':
                    if needs['SG'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['SG'] -= 1
                        break
                    if needs['PG_SG'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['PG_SG'] -= 1
                        break
                    if needs['Util'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['Util'] -= 1
                        break
                    else:
                        continue
                if line[4] == 'SF':
                    if needs['SF'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['SF'] -= 1
                        break
                    if needs['SF_PF'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['SF_PF'] -= 1
                        break
                    if needs['Util'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['Util'] -= 1
                        break
                    else:
                        continue
                if line[4] == 'PF':
                    if needs['PF'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['PF'] -= 1
                        break
                    if needs['SF_PF'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['SF_PF'] -= 1
                        break
                    if needs['Util'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['Util'] -= 1
                        break
                    else:
                        continue
                if line[4] == 'C':
                    if needs['C'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['C'] -= 1
                        break
                    if needs['Util'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['Util'] -= 1
                        break
                    else:
                        continue

    budget -= line[5]
    spots -= 1
    spent += line[5]
#     pred_output.append(line[7])
    output.append(line[8])
    
print('Budget used: ',spent)
print(positions)
# print('Predicted team output: ',sum(pred_output))
print('Actual team output: ',sum(output))
for i,e in zip(roster, output):
    print(i,e)
# Out:
# Budget used:  49500
# ['PF', 'SG', 'SG', 'SG', 'SF', 'SF', 'C', 'PG']
# Actual team output:  377.25
# Draymond Green 55.5
# Nicolas Batum 33.75
# Lou Williams 33.5
# Tim Hardaway Jr. 50.25
# DeMarre Carroll 46.5
# Tyreke Evans 49.25
# DeAndre Jordan 59.25
# Kyle Lowry 49.25

# %%
results = []
for date in date_range:
    day = data.loc[(data.DATE == date)]
    day.sort_values('magic_number_knn_20', ascending = False, inplace=True)
    budget = 50000
    spots = 8
    roster = []
    positions = []
    needs = {'PG': 1,'SG': 1,'SF': 1,'PF': 1,'C': 1,'PG_SG': 1,'SF_PF': 1 ,'Util': 1}
    pred_output = []
    output = []
    spent = 0
    while spots >= 1:
        for line in day.itertuples():
            if line[5] <= (budget/spots):   #6250
                if line[2] not in roster:
                    if line[4] == 'PG':
                        if needs['PG'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['PG'] -= 1
                            break
                        if needs['PG_SG'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['PG_SG'] -= 1
                            break
                        if needs['Util'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['Util'] -= 1
                            break
                        else:
                            continue
                    if line[4] == 'SG':
                        if needs['SG'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['SG'] -= 1
                            break
                        if needs['PG_SG'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['PG_SG'] -= 1
                            break
                        if needs['Util'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['Util'] -= 1
                            break
                        else:
                            continue
                    if line[4] == 'SF':
                        if needs['SF'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['SF'] -= 1
                            break
                        if needs['SF_PF'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['SF_PF'] -= 1
                            break
                        if needs['Util'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['Util'] -= 1
                            break
                        else:
                            continue
                    if line[4] == 'PF':
                        if needs['PF'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['PF'] -= 1
                            break
                        if needs['SF_PF'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['SF_PF'] -= 1
                            break
                        if needs['Util'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['Util'] -= 1
                            break
                        else:
                            continue
                    if line[4] == 'C':
                        if needs['C'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['C'] -= 1
                            break
                        if needs['Util'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['Util'] -= 1
                            break
                        else:
                            continue

        budget -= line[5]
        spots -= 1
        spent += line[5]
        output.append(line[8])
    print(date, sum(output))
    results.append(sum(output))
# Out:
# /Users/willhall/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# 02/01/2018 284.25
# 02/02/2018 236.25
# 02/03/2018 288.0
# 02/04/2018 231.75
# 02/05/2018 289.5
# 02/06/2018 269.0
# 02/07/2018 256.5
# 02/08/2018 281.5
# 02/09/2018 257.5
# 02/10/2018 302.0
# 02/11/2018 344.25
# 02/12/2018 295.25
# 02/13/2018 273.25
# 02/14/2018 377.25
# 02/15/2018 224.5
# 02/22/2018 268.25
# 02/23/2018 297.0
# 02/24/2018 231.25
# 02/25/2018 288.5
# 02/26/2018 268.75
# 02/27/2018 303.0
# 02/28/2018 237.5
# 03/01/2018 311.75
# 03/02/2018 328.75
# 03/03/2018 292.5
# 03/04/2018 273.5
# 03/05/2018 220.75
# 03/06/2018 267.75
# 03/07/2018 285.75
# 03/08/2018 260.0
# 03/09/2018 283.25
# 03/10/2018 181.0
# 03/11/2018 280.5
# 03/12/2018 268.25
# 03/13/2018 313.25
# 03/14/2018 286.5
# 03/15/2018 277.75
# 03/16/2018 266.0
# 03/17/2018 287.5
# 03/18/2018 298.5
# 03/19/2018 297.75
# 03/20/2018 272.25
# 03/21/2018 290.0
# 03/22/2018 247.75
# 03/23/2018 276.0
# 03/24/2018 278.75
# 03/25/2018 259.5
# 03/26/2018 262.5
# 03/27/2018 295.5
# 03/28/2018 293.0
# 03/29/2018 244.0
# 03/30/2018 318.25
# 03/31/2018 245.5

# %%
series = pd.Series(results)

# %%
series.describe()
# Out:
# count     53.000000
# mean     276.773585
# std       32.166045
# min      181.000000
# 25%      260.000000
# 50%      278.750000
# 75%      293.000000
# max      377.250000
# dtype: float64

# %%
# 260-270 usually is a cash in a 50/50 on DK. 280 will cash 95% of the time in 50/50's on DK
