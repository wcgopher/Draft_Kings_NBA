# %%
sklearn.linear_model.Ridge()
sklearn.linear_model.Lasso()
sklearn.linear_model.MultiTaskLasso()
sklearn.linear_model.ElasticNet()
sklearn.linear_model.MultiTaskElasticNet()
sklearn.linear_model.Lars()
sklearn.linear_model.LassoLars()
sklearn.linear_model.BayesianRidge()
sklearn.svm.SVR()
sklearn.svm.NuSVR()
sklearn.linear_model.SGDRegressor()
#Finding a reasonable regularization term \alpha is best done using GridSearchCV, usually in the range 10.0**-np.arange(1,7).
sklearn.neighbors.KNeighborsRegressor()
sklearn.gaussian_process.GaussianProcessRegressor()
sklearn.tree.DecisionTreeRegressor()
sklearn.ensemble.RandomForestRegressor()
sklearn.ensemble.GradientBoostingRegressor()
sklearn.neural_network.MLPRegressor()

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_pickle('player_2016_2018.pkl')

# %%
data.DK_POS.unique()
# Out:
# array(['SF', 'PF', 'C', 'SG', 'PG', 'PF/C', 'SF/PF', 'SG/SF', 'PG/SG',
#        'PG/SF', nan], dtype=object)

# %%
for pos in data.DK_POS.unique():
    print(type(pos))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>

# %%
positions = data.loc[data.DK_POS.isnull() == False]

# %%
positions.tail(10)
# Out:
#        C_DK_PTS        DATE        DEFF  DEFF_roll10  DEFF_roll25  DEFF_roll3  \
# 25880     20.25  04/12/2017  100.916886   114.319823   107.455578  119.179576
# 25881     20.25  04/12/2017  100.916886   114.319823   107.455578  119.179576
# 25882      0.00  04/12/2017  103.944393   107.885161   108.656607  101.477279
# 25883      0.00  04/12/2017  103.944393   107.885161   108.656607  101.477279
# 25884      0.00  04/12/2017  103.944393   107.885161   108.656607  101.477279
# 25885      0.00  04/12/2017  103.944393   107.885161   108.656607  101.477279
# 25886      0.00  04/12/2017  103.944393   107.885161   108.656607  101.477279
# 25887      0.00  04/12/2017  103.944393   107.885161   108.656607  101.477279
# 25888      0.00  04/12/2017  103.944393   107.885161   108.656607  101.477279
# 25889      0.00  04/12/2017  103.944393   107.885161   108.656607  101.477279
#
#        DEFF_roll5 DK_POS DK_SAL  DraftKings_PTS     ...      \
# 25880  121.433318     SG   5200           24.75     ...
# 25881  121.433318     SF   3500           11.25     ...
# 25882  109.251197  SG/SF   4800           14.00     ...
# 25883  109.251197   PF/C   4200           40.25     ...
# 25884  109.251197      C   3800           21.75     ...
# 25885  109.251197     PF   3000           18.50     ...
# 25886  109.251197     PG   5000           34.50     ...
# 25887  109.251197     SF   3800           39.25     ...
# 25888  109.251197  SF/PF   3900           18.50     ...
# 25889  109.251197     PG   3000           21.00     ...
#
#        opp_SF_allowed_roll3  opp_SF_allowed_roll5  opp_SG_allowed  \
# 25880             71.166667                  72.6           74.25
# 25881             71.166667                  72.6           74.25
# 25882             51.750000                  56.5           45.25
# 25883             51.750000                  56.5           45.25
# 25884             51.750000                  56.5           45.25
# 25885             51.750000                  56.5           45.25
# 25886             51.750000                  56.5           45.25
# 25887             51.750000                  56.5           45.25
# 25888             51.750000                  56.5           45.25
# 25889             51.750000                  56.5           45.25
#
#        opp_SG_allowed_roll10  opp_SG_allowed_roll25  opp_SG_allowed_roll3  \
# 25880                  52.55                  51.05             60.750000
# 25881                  52.55                  51.05             60.750000
# 25882                  33.80                  40.93             33.833333
# 25883                  33.80                  40.93             33.833333
# 25884                  33.80                  40.93             33.833333
# 25885                  33.80                  40.93             33.833333
# 25886                  33.80                  40.93             33.833333
# 25887                  33.80                  40.93             33.833333
# 25888                  33.80                  40.93             33.833333
# 25889                  33.80                  40.93             33.833333
#
#        opp_SG_allowed_roll5  Start  DK_PTS_PER_MIN       VALUE
# 25880                 54.95    0.0        1.093681  0.00475962
# 25881                 54.95    0.0        0.538793  0.00321429
# 25882                 29.40    0.0        0.617284  0.00291667
# 25883                 29.40    0.0        1.054217  0.00958333
# 25884                 29.40    0.0        0.612159  0.00572368
# 25885                 29.40    0.0        0.497045  0.00616667
# 25886                 29.40    0.0        1.328456      0.0069
# 25887                 29.40    0.0        1.087258   0.0103289
# 25888                 29.40    0.0        0.830341  0.00474359
# 25889                 29.40    0.0        0.953246       0.007
#
# [10 rows x 87 columns]
