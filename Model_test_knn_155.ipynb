# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_pickle('Prediction_master_number_attempt_knn_155.pkl')
data.columns
# Out:
# Index(['DATE', 'PLAYER', 'TEAM', 'POSITION', 'DK_SAL', 'DK_PTS_PER_MIN',
#        'MINUTES', 'DraftKings_PTS', 'magic_number_knn_155'],
#       dtype='object')

# %%
dates = data.DATE.unique()
date_range = ['02/01/2018', '02/02/2018', '02/03/2018', '02/04/2018',
       '02/05/2018', '02/06/2018', '02/07/2018', '02/08/2018',
       '02/09/2018', '02/10/2018', '02/11/2018', '02/12/2018',
       '02/13/2018', '02/14/2018', '02/15/2018', '02/22/2018',
       '02/23/2018', '02/24/2018', '02/25/2018', '02/26/2018',
       '02/27/2018', '02/28/2018', '03/01/2018', '03/02/2018',
       '03/03/2018', '03/04/2018', '03/05/2018', '03/06/2018',
       '03/07/2018', '03/08/2018', '03/09/2018', '03/10/2018',
       '03/11/2018', '03/12/2018', '03/13/2018', '03/14/2018',
       '03/15/2018', '03/16/2018', '03/17/2018', '03/18/2018',
       '03/19/2018', '03/20/2018', '03/21/2018', '03/22/2018',
       '03/23/2018', '03/24/2018', '03/25/2018', '03/26/2018',
       '03/27/2018', '03/28/2018', '03/29/2018', '03/30/2018',
       '03/31/2018']

# %%
day = data.loc[(data.DATE == '03/18/2018')]

# %%
day.sort_values('magic_number_knn_155', ascending = False, inplace=True)

day
# Out:
# /Users/willhall/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#              DATE               PLAYER         TEAM POSITION  DK_SAL  \
# 47566  03/18/2018         James Harden      Houston       PG   11000
# 47551  03/18/2018        Anthony Davis  New Orleans       PF   11400
# 47574  03/18/2018   Karl-Anthony Towns    Minnesota        C    9400
# 47585  03/18/2018       Damian Lillard     Portland       PG    9700
# 47567  03/18/2018           Chris Paul      Houston       PG    7800
# 47576  03/18/2018          Jeff Teague    Minnesota       PG    5900
# 47599  03/18/2018         Lou Williams  LA Clippers       SG    7300
# 47584  03/18/2018          CJ McCollum     Portland       SG    7100
# 47553  03/18/2018         Jrue Holiday  New Orleans       PG    7900
# 47596  03/18/2018       DeAndre Jordan  LA Clippers        C    7700
# 47575  03/18/2018       Andrew Wiggins    Minnesota       SF    6100
# 47565  03/18/2018         Clint Capela      Houston        C    6400
# 47539  03/18/2018           Al Horford       Boston        C    6900
# 47583  03/18/2018         Jusuf Nurkic     Portland        C    6300
# 47582  03/18/2018      Al-Farouq Aminu     Portland       SF    4400
# 47556  03/18/2018       Nikola Mirotic  New Orleans       PF    5000
# 47580  03/18/2018         Derrick Rose    Minnesota       PG    3100
# 47563  03/18/2018         Trevor Ariza      Houston       SF    4700
# 47595  03/18/2018        Tobias Harris  LA Clippers       PF    7500
# 47543  03/18/2018          Greg Monroe       Boston        C    5100
# 47538  03/18/2018        Marcus Morris       Boston       SF    6000
# 47569  03/18/2018          Eric Gordon      Houston       SG    5200
# 47541  03/18/2018         Jayson Tatum       Boston       SF    5700
# 47598  03/18/2018        Austin Rivers  LA Clippers       SG    5800
# 47554  03/18/2018          Rajon Rondo  New Orleans       PG    5500
# 47573  03/18/2018           Taj Gibson    Minnesota       PF    4900
# 47600  03/18/2018     Montrezl Harrell  LA Clippers       PF    4600
# 47578  03/18/2018       Jamal Crawford    Minnesota       SG    3600
# 47572  03/18/2018      Nemanja Bjelica    Minnesota       PF    5600
# 47570  03/18/2018        Ryan Anderson      Houston       PF    3800
# ...           ...                  ...          ...      ...     ...
# 47552  03/18/2018         Emeka Okafor  New Orleans        C    3600
# 47597  03/18/2018       Milos Teodosic  LA Clippers       PG    4300
# 47590  03/18/2018       Shabazz Napier     Portland       PG    4000
# 47604  03/18/2018      Sean Kilpatrick  LA Clippers       SG    3000
# 47586  03/18/2018             Ed Davis     Portland       PF    3900
# 47594  03/18/2018  Sindarius Thornwell  LA Clippers       SG    3400
# 47544  03/18/2018          Abdel Nader       Boston       SF    3400
# 47571  03/18/2018         Gerald Green      Houston       SG    3400
# 47603  03/18/2018     Boban Marjanovic  LA Clippers        C    3300
# 47568  03/18/2018     Luc Mbah a Moute      Houston       PF    3200
# 47560  03/18/2018        Darius Miller  New Orleans       SF    3400
# 47589  03/18/2018         Zach Collins     Portland        C    3400
# 47540  03/18/2018          Aron Baynes       Boston        C    3600
# 47601  03/18/2018          Jawun Evans  LA Clippers       PG    3200
# 47546  03/18/2018         Shane Larkin       Boston       PG    3700
# 47577  03/18/2018           Tyus Jones    Minnesota       PG    3400
# 47555  03/18/2018            Ian Clark  New Orleans       SG    3400
# 47602  03/18/2018       Wesley Johnson  LA Clippers       SF    3100
# 47605  03/18/2018           Sam Dekker  LA Clippers       SF    3000
# 47591  03/18/2018       Meyers Leonard     Portland       PF    3000
# 47547  03/18/2018   Guerschon Yabusele       Boston       PF    3200
# 47545  03/18/2018         Semi Ojeleye       Boston       PF    3300
# 47588  03/18/2018      Pat Connaughton     Portland       SG    3000
# 47548  03/18/2018         Kadeem Allen       Boston       SG    3000
# 47558  03/18/2018        Larry Drew II  New Orleans       PG    3000
# 47549  03/18/2018          Jabari Bird       Boston       SG    3000
# 47592  03/18/2018       Caleb Swanigan     Portland       PF    3000
# 47561  03/18/2018        Charles Cooke  New Orleans       SG    3000
# 47562  03/18/2018      DeAndre Liggins  New Orleans       SG    3000
# 47593  03/18/2018          Jake Layman     Portland       SF    3000
#
#        DK_PTS_PER_MIN  MINUTES  DraftKings_PTS  magic_number_knn_155
# 47566        1.727891    36.75           63.50              0.001545
# 47551        1.758833    32.55           57.25              0.001334
# 47574        1.355932    35.40           48.00              0.001209
# 47585        0.913462    31.20           28.50              0.001074
# 47567        1.228324    34.60           42.50              0.001062
# 47576        1.427406    36.78           52.50              0.000943
# 47599        1.290892    31.18           40.25              0.000920
# 47584        1.131466    32.48           36.75              0.000904
# 47553        0.646018    28.25           18.25              0.000887
# 47596        1.042391    28.78           30.00              0.000885
# 47575        0.806227    35.97           29.00              0.000863
# 47565        1.322920    31.37           41.50              0.000853
# 47539        0.607577    27.98           17.00              0.000828
# 47583        1.394958    29.75           41.50              0.000768
# 47582        1.298503    32.73           42.50              0.000755
# 47556        1.927337    22.57           43.50              0.000740
# 47580        0.997409    19.30           19.25              0.000735
# 47563        0.740353    33.43           24.75              0.000721
# 47595        0.597750    35.55           21.25              0.000708
# 47543        0.955166    25.65           24.50              0.000683
# 47538        0.923749    29.77           27.50              0.000673
# 47569        0.341439    30.02           10.25              0.000672
# 47541        1.278984    27.17           34.75              0.000671
# 47598        0.715829    37.02           26.50              0.000664
# 47554        0.794753    32.40           25.75              0.000656
# 47573        0.361752    25.57            9.25              0.000631
# 47600        2.126866    20.10           42.75              0.000609
# 47578        1.033058    27.83           28.75              0.000576
# 47572        0.778375    35.33           27.50              0.000567
# 47570        1.142514    16.63           19.00              0.000566
# ...               ...      ...             ...                   ...
# 47552        1.081939    17.33           18.75              0.000497
# 47597        0.484155    22.72           11.00              0.000477
# 47590        1.203870    22.22           26.75              0.000471
# 47604        0.511945     2.93            1.50              0.000451
# 47586        0.743657    11.43            8.50              0.000432
# 47594        0.402122    29.22           11.75              0.000398
# 47544        0.777984    21.53           16.75              0.000396
# 47571        0.978037    14.57           14.25              0.000391
# 47603        1.001705    11.73           11.75              0.000375
# 47568        0.578947    19.00           11.00              0.000371
# 47560        0.674091     8.53            5.75              0.000360
# 47589        0.428195    15.18            6.50              0.000357
# 47540        0.808720    14.22           11.50              0.000342
# 47601        0.494792     9.60            4.75              0.000330
# 47546        0.377426    27.82           10.50              0.000330
# 47577        0.133690    11.22            1.50              0.000325
# 47555        0.739875    25.68           19.00              0.000323
# 47602        0.790960     8.85            7.00              0.000301
# 47605        0.862069     2.32            2.00              0.000301
# 47591        0.735294     4.42            3.25              0.000298
# 47547        1.418440     4.23            6.00              0.000295
# 47545        0.288832    23.37            6.75              0.000267
# 47588        0.316456    10.27            3.25              0.000262
# 47548        0.768156     3.58            2.75              0.000253
# 47558        0.265487     5.65            1.50              0.000249
# 47549        0.230769     3.25            0.75              0.000225
# 47592       -0.215517     2.32           -0.50              0.000215
# 47561        0.000000     3.25            0.00              0.000214
# 47562        0.000000     3.25            0.00              0.000201
# 47593       -0.215517     2.32           -0.50              0.000140
#
# [67 rows x 9 columns]

# %%
budget = 50000
spots = 8
roster = []
positions = []
needs = {'PG': 1,'SG': 1,'SF': 1,'PF': 1,'C': 1,'PG_SG': 1,'SF_PF': 1 ,'Util': 1}
pred_output = []
output = []
spent = 0
while spots >= 1:
    for line in day.itertuples():
        if line[5] <= (budget/spots):   #6250
            if line[2] not in roster:
                if line[4] == 'PG':
                    if needs['PG'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['PG'] -= 1
                        break
                    if needs['PG_SG'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['PG_SG'] -= 1
                        break
                    if needs['Util'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['Util'] -= 1
                        break
                    else:
                        continue
                if line[4] == 'SG':
                    if needs['SG'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['SG'] -= 1
                        break
                    if needs['PG_SG'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['PG_SG'] -= 1
                        break
                    if needs['Util'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['Util'] -= 1
                        break
                    else:
                        continue
                if line[4] == 'SF':
                    if needs['SF'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['SF'] -= 1
                        break
                    if needs['SF_PF'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['SF_PF'] -= 1
                        break
                    if needs['Util'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['Util'] -= 1
                        break
                    else:
                        continue
                if line[4] == 'PF':
                    if needs['PF'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['PF'] -= 1
                        break
                    if needs['SF_PF'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['SF_PF'] -= 1
                        break
                    if needs['Util'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['Util'] -= 1
                        break
                    else:
                        continue
                if line[4] == 'C':
                    if needs['C'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['C'] -= 1
                        break
                    if needs['Util'] == 1:
                        roster.append(line[2])
                        positions.append(line[4])
                        needs['Util'] -= 1
                        break
                    else:
                        continue

    budget -= line[5]
    spots -= 1
    spent += line[5]
#     pred_output.append(line[7])
    output.append(line[8])
    
print('Budget used: ',spent)
print(positions)
# print('Predicted team output: ',sum(pred_output))
print('Actual team output: ',sum(output))
for i,e in zip(roster, output):
    print(i,e)
# Out:
# Budget used:  49200
# ['PG', 'SF', 'C', 'SF', 'C', 'PF', 'PG', 'SG']
# Actual team output:  333.25
# Jeff Teague 52.5
# Andrew Wiggins 29.0
# Jusuf Nurkic 41.5
# Al-Farouq Aminu 42.5
# Clint Capela 41.5
# Nikola Mirotic 43.5
# Chris Paul 42.5
# Lou Williams 40.25

# %%
results = []
for date in date_range:
    day = data.loc[(data.DATE == date)]
    day.sort_values('magic_number_knn_155', ascending = False, inplace=True)
    budget = 50000
    spots = 8
    roster = []
    positions = []
    needs = {'PG': 1,'SG': 1,'SF': 1,'PF': 1,'C': 1,'PG_SG': 1,'SF_PF': 1 ,'Util': 1}
    pred_output = []
    output = []
    spent = 0
    while spots >= 1:
        for line in day.itertuples():
            if line[5] <= (budget/spots):   #6250
                if line[2] not in roster:
                    if line[4] == 'PG':
                        if needs['PG'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['PG'] -= 1
                            break
                        if needs['PG_SG'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['PG_SG'] -= 1
                            break
                        if needs['Util'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['Util'] -= 1
                            break
                        else:
                            continue
                    if line[4] == 'SG':
                        if needs['SG'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['SG'] -= 1
                            break
                        if needs['PG_SG'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['PG_SG'] -= 1
                            break
                        if needs['Util'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['Util'] -= 1
                            break
                        else:
                            continue
                    if line[4] == 'SF':
                        if needs['SF'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['SF'] -= 1
                            break
                        if needs['SF_PF'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['SF_PF'] -= 1
                            break
                        if needs['Util'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['Util'] -= 1
                            break
                        else:
                            continue
                    if line[4] == 'PF':
                        if needs['PF'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['PF'] -= 1
                            break
                        if needs['SF_PF'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['SF_PF'] -= 1
                            break
                        if needs['Util'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['Util'] -= 1
                            break
                        else:
                            continue
                    if line[4] == 'C':
                        if needs['C'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['C'] -= 1
                            break
                        if needs['Util'] == 1:
                            roster.append(line[2])
                            positions.append(line[4])
                            needs['Util'] -= 1
                            break
                        else:
                            continue

        budget -= line[5]
        spots -= 1
        spent += line[5]
        output.append(line[8])
    print(date, sum(output))
    results.append(sum(output))
# Out:
# /Users/willhall/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# 02/01/2018 258.75
# 02/02/2018 241.25
# 02/03/2018 237.25
# 02/04/2018 273.0
# 02/05/2018 281.5
# 02/06/2018 202.25
# 02/07/2018 291.5
# 02/08/2018 290.0
# 02/09/2018 229.0
# 02/10/2018 293.75
# 02/11/2018 322.25
# 02/12/2018 294.25
# 02/13/2018 292.25
# 02/14/2018 288.75
# 02/15/2018 233.5
# 02/22/2018 280.5
# 02/23/2018 294.0
# 02/24/2018 218.5
# 02/25/2018 267.0
# 02/26/2018 238.0
# 02/27/2018 260.5
# 02/28/2018 258.5
# 03/01/2018 322.75
# 03/02/2018 318.25
# 03/03/2018 321.75
# 03/04/2018 293.25
# 03/05/2018 269.25
# 03/06/2018 279.75
# 03/07/2018 261.75
# 03/08/2018 261.0
# 03/09/2018 282.25
# 03/10/2018 197.0
# 03/11/2018 307.5
# 03/12/2018 268.25
# 03/13/2018 254.5
# 03/14/2018 325.5
# 03/15/2018 249.25
# 03/16/2018 260.5
# 03/17/2018 307.5
# 03/18/2018 333.25
# 03/19/2018 311.25
# 03/20/2018 278.5
# 03/21/2018 300.0
# 03/22/2018 256.25
# 03/23/2018 250.75
# 03/24/2018 310.5
# 03/25/2018 266.75
# 03/26/2018 315.5
# 03/27/2018 259.5
# 03/28/2018 280.25
# 03/29/2018 223.25
# 03/30/2018 326.0
# 03/31/2018 249.75

# %%
series = pd.Series(results)

# %%
series.describe()
# Out:
# count     53.000000
# mean     275.240566
# std       32.849195
# min      197.000000
# 25%      256.250000
# 50%      278.500000
# 75%      294.250000
# max      333.250000
# dtype: float64
